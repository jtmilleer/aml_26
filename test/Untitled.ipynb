# %%
# %run test.py
# Out:
# 3.14.2 | packaged by Anaconda, Inc. | (main, Dec 19 2025, 11:44:48) [MSC v.1929 64 bit (AMD64)]
# - matplotlib: 3.10.8
# - numpy: 2.4.1
# - pandas: 2.3.3
# - scikit-learn: 1.8.0
# - scipy: 1.17.0
# - seaborn: 0.13.2
# - statsmodels: 0.14.6
# all libs found
